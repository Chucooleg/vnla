# %%
import json
import numpy as np
from analysis import OutputData, PlotData

# %%
with open("/home/hoyeung/blob_experiments/asknav/main_learned_nav_sample_ask_teacher/20191102_eval_khanh_main_learned_nav_sample_ask_teacher/main_learned_nav_sample_ask_teacher_test_unseen_for_eval.json", "rb") as f:
    raw_test_unseen = json.load(f)

# %%
test_unseen = OutputData(raw_test_unseen)

# %%
test_unseen.compute_entropy_output_data()

# %%
test_unseen.compute_cross_entropy_output_data()

# %%
test_unseen.compute_nav_argmax_output_data()

# %%
list(test_unseen[5])
# Out:
# ['instr_id',
#  'teacher_ask',
#  'agent_ask_logits',
#  'trajectory',
#  'teacher_ask_reason',
#  'agent_nav',
#  'agent_nav_logits_final',
#  'teacher_nav',
#  'agent_nav_softmax_initial',
#  'subgoals',
#  'agent_nav_softmax_final',
#  'scan',
#  'agent_nav_logits_initial',
#  'agent_ask',
#  'agent_nav_ent_initial',
#  'agent_nav_ent_final',
#  'agent_ask_ent',
#  'agent_nav_cross_ent_initial',
#  'agent_nav_cross_ent_final',
#  'agent_ask_cross_ent',
#  'agent_nav_argmax_initial',
#  'agent_nav_argmax_final']

# %% [markdown]
# ## Plotting

# %%
plotdata = PlotData(test_unseen)

# %% [markdown]
# ## 1. Agent Ask Prediction (entropy)

# %%
plotdata.plot_by_action_type("ask")
# Out:
# count = 76085
# count = 989
# count = 3745
# count = 10219

# %% [markdown]
# ## 2. Initial Agent Nav Prediction  (nav p1)

# %%
plotdata.plot_by_action_type("nav_initial")
# Out:
# count = 17892
# count = 5610
# count = 109
# count = 58
# count = 4523
# count = 234
# count = 6529
# count = 16472
# count = 45
# count = 67
# count = 4519
# count = 223
# count = 64
# count = 80
# count = 433
# count = 0
# count = 104
# count = 1
# count = 131
# count = 148
# count = 6
# count = 364
# count = 250
# count = 7
# count = 3709
# count = 3198
# count = 192
# count = 240
# count = 20138
# count = 93
# count = 1674
# count = 1513
# count = 25
# count = 13
# count = 937
# count = 1437

# %% [markdown]
# ## 3. Final Agent Nav Prediction  (nav p2)

# %%
plotdata.plot_by_action_type("nav_final")
# Out:
# count = 20399
# count = 5006
# count = 81
# count = 43
# count = 2730
# count = 167
# count = 5570
# count = 19307
# count = 20
# count = 46
# count = 2776
# count = 136
# count = 14
# count = 37
# count = 568
# count = 0
# count = 63
# count = 0
# count = 80
# count = 86
# count = 5
# count = 544
# count = 187
# count = 4
# count = 1687
# count = 1483
# count = 80
# count = 119
# count = 24154
# count = 47
# count = 1577
# count = 1433
# count = 25
# count = 12
# count = 615
# count = 1937
